# %%
'''
Skeleton code for resolution theorem prover for propositional logic

Yoonsuck Choe
10/20/2021

clause representation:

  [<positive-proposition-list>, <negative-proposition-list>]

proposition-list representation:

  [ 'p', 'q', 'r' ]

  Note: 'p', 'q', 'r', 's' are propositions : CASE SENSITIVE!

Example clause:

  [['p', 'q'] ['r']] : This is clause P \/ Q \/ ~R

'''

DEBUG=True

#---------------------------------------------------------------------
def rm_item(lst, item):
#---------------------------------------------------------------------
  '''
  function: rm_pred()

  remove item from list
  - return [] if empty, not None
  '''
  lst.remove(item)

  if lst == None:
    return []
  else:
    return lst


#---------------------------------------------------------------------
def mk_unique(clause):
#---------------------------------------------------------------------
  '''
  remove redundant propositions in the clause
  '''
  pos = clause[0]
  neg = clause[1]

  pos = list(set(pos))
  neg = list(set(neg))

  return [pos, neg]

#---------------------------------------------------------------------
def resolve(clause1, clause2):
#---------------------------------------------------------------------
  '''
  function: resolve()

  [['p', 'q'] ['r']] : clause P \/ Q \/ ~R

  resolve clauses c1 and c2
  - if resolvable returns resolvent
  - if not resolvable returns False
  - returns empty clause [[], []] when Falsified

  CAUTION: this is not perfect.
  '''

  # remove any redundant propositions in the clauses
  c1 = mk_unique(clause1)
  c2 = mk_unique(clause2)

  count = 0

  # print clauses
  if DEBUG:
    print("resolving: "+str(c1)+" and "+str(c2))

  # c1 pos vs. c2 neg
  for p1 in c1[0]:
    for p2 in c2[1]:
      if p1==p2:
        c1 = [rm_item(c1[0],p1), c1[1]]
        c2 = [c2[0], rm_item(c2[1],p2)]
        count = count+1

  # c2 pos vs. c1 neg
  for p1 in c1[1]:
    for p2 in c2[0]:
      if p1==p2:
        c1 = [c1[0], rm_item(c1[1],p1)]
        c2 = [rm_item(c2[0],p2), c2[1]]
        count = count+1

  # check for multiple matches or no match and abort if so.
  if count>1 or count==0:
    return False

  # compute resolvent
  c1[0].extend(c2[0])
  c1[1].extend(c2[1])

  # make unique and return

  return mk_unique(c1)



#---------------------------------------------------------------------
def null_p(clause):
#---------------------------------------------------------------------
  '''
  function null_p()

  check if "False" is derived
  - returns True if empty clause
  - returns False if non-empty clause
  '''

  if (type(clause) is list) and len(clause[0]) + len(clause[1]) == 0:
    return True
  else:
    return False



#---------------------------------------------------------------------
def print_clause(clause):
#---------------------------------------------------------------------
  '''
  function print_clause

  See function resolve() for clause representation.

  '''

  s = ""
  for pos in clause[0]:
    s = s+pos+"\/"

  for neg in clause[1]:
    s = s+"~"+neg+"\/"

  if len(s)==0:
    print("NULL")
  else:
    n=len(s)
    print(s[0:(n-2)])

#------------------------------------------------------
# test resolve() function
#------------------------------------------------------

print("\ntest1")
test1 = resolve([['p', 'q'], ['r']], [[], ['p']])
print("resolvent = "+str(test1))
print("null? "+str(null_p(test1)))

print("\ntest2")
test2 = resolve([['p'], []], [[], ['p']])
print("resolvent = "+str(test2))
print("null? "+str(null_p(test2)))

print("\ntest3")
test3 = resolve([['p', 'q'], ['r']], [['r'], ['p']])
print("resolvent = "+str(test3))
print("null? "+str(null_p(test3)))

print("\ntest4")
test4 = resolve([['p', 'q'], ['r']], [['r'], []])
print("resolvent = "+str(test4))
print("null? "+str(null_p(test4)))


print("\ntest5")
test5 = resolve([['p', 'q'], ['r']], [['p', 'r'], []])
print("resolvent = "+str(test5))
print("null? "+str(null_p(test5)))


# edge case not being handled correctly: p \/ q \/ ~r \/ ~r  vs. p \/ r should give p \/ q, not p \/ q \/ ~r
# - now this is fixed, with the use of mk_unique()
print("\ntest6")
test5 = resolve([['p', 'q'], ['r', 'r']], [['p', 'r'], []])
print("resolvent = "+str(test5))
print("null? "+str(null_p(test5)))
# Out:
# test1
# resolving: [['p', 'q'], ['r']] and [[], ['p']]
# resolvent = [['q'], ['r']]
# null? False
#
# test2
# resolving: [['p'], []] and [[], ['p']]
# resolvent = [[], []]
# null? True
#
# test3
# resolving: [['p', 'q'], ['r']] and [['r'], ['p']]
# resolvent = False
# null? False
#
# test4
# resolving: [['p', 'q'], ['r']] and [['r'], []]
# resolvent = [['p', 'q'], []]
# null? False
#
# test5
# resolving: [['p', 'q'], ['r']] and [['p', 'r'], []]
# resolvent = [['p', 'q'], []]
# null? False
#
# test6
# resolving: [['p', 'q'], ['r']] and [['p', 'r'], []]
# resolvent = [['p', 'q'], []]
# null? False

# %%
'''
Using the resolve() function and the null_p function, implement the two-pointer method for propositional logic theorem proving
- use set of support

theorem representation:

[ [<index> <clause1>], [<index> <clause2>], ... ]

index : integer

clause representation:

[<positive-proposition-list>, <negative-proposition-list>]

proposition-list representation:

[ 'p', 'q', 'r' ]

'''

# define your theorem, as a set of indexed clauses

theorem = [    # pos-list      # neg-list
           [0, [['p','q'],    ['r']]],       # clause 0     P \/ Q \/ ~R
           [1, [['s'],        ['q']]],       # clause 1     S \/ ~Q
           [2, [['t'],        ['s']]],       # clause 2     T \/ ~S
           [3, [[],           ['p']]],       # clause 3     ~P   - negated conclusion starts here (goal clause index = 3)
           [4, [['r'],        []]],          # clause 4     R
           [5, [[],           ['t']]]        # clause 5     ~T
          ]


theorem2 = [ # pos-list      # neg-list
           [0, [['i'],        ['m']]],       # clause 0     ~M \/ I
           [1, [['m'],        ['i']]],       # clause 1      M \/ ~I
           [2, [['m','l'],    []]],          # clause 2      M \/ L
           [3, [['h'],        ['i']]],       # clause 3     ~I \/ H
           [4, [['h'],        ['l']]],       # clause 4     ~L \/ H
           [5, [['g'],        ['h']]],       # clause 5     ~H \/ G
           [6, [[],           ['h']]]        # clause 6     ~H - negated conclusion starts here (goal clause index = 6)
           ]  # enter the example theorm in the homework

theorem3 = [ # pos-list      # neg-list
           [0, [['a'],        []]],          # clause 0     A
           [1, [['b'],        []]],          # clause 1     B
           [2, [['d'],        []]],          # clause 2     D
           [3, [['c'],        ['a','b']]],   # clause 3     ~A \/ ~B \/ C
           [4, [['e'],        ['c','d']]],   # clause 4     ~C \/ ~D \/ E
           [5, [[],           ['e']]]        # clause 5     ~E - negated conclusion starts here (goal clause index = 5)
            ]  # enter your own example for testing


#------------------------------------------------------
# prover() function : you must implement this function
#---------------------------------------------------------------------
def prover(thm, goal):
#---------------------------------------------------------------------
  '''
  function prover: implement this

  two-pointer method, with set of support
  - arguments:
    thm : theorem
    goal : integer index (clause number where the negated conclusion starts)
  - show resolution steps
  - if null_p checks, return True (theorem proven)
  - otherwise return False
  '''

  print('\nprover():\n\nTheorem:')

  for clause in thm:
    print("clause "+str(clause[0])+": ",end="")
    print_clause(clause[1])

  print('Goal clause index=',end='')
  print(goal)

  #print('Test resolve: clause 0 and clause 1')
  #print_clause(resolve(theorem[0][1], theorem[1][1]))

  #print('\n\n--- must print the resolution steps\n\n\n')

  #initalized pointer
  inner = 0
  outer = goal
  new_clause_count = 0

  while outer < len(thm):
    resolvent = resolve(thm[inner][1],thm[outer][1])

    # If resolvent is possible
    if resolvent:
      #if resolvent is not in the thm
      if resolvent not in [clause[1] for clause in thm]:
        new_clause_count += 1
        print("New clause from resolution of", inner, "and", outer, ":" , end="")
        print_clause(resolvent)
        thm.append([len(thm), resolvent])

      #check resolvent is empty or not
      #return True -> no more new clauses and derived to False
      if null_p(resolvent):
        print("\nEmpty clause derived. Theorem is proven!")
        print("\nNew Clauses with including null: ", new_clause_count)
        print("\nNew Clauses with not including null: ", new_clause_count-1,"\n")
        #print(thm)
        #success
        return True

    #move pointer
    inner += 1

    #check pointers
    if inner == outer:
      inner = 0
      outer += 1


  print("\nTheorem is not provable with given clauses.")
  print("\nNew Clauses Generated: ", new_clause_count)
  return False

#------------------------------------------------------
# test prover() function
#------------------------------------------------------

# Test prover on example theorem

prover(theorem, 3)

# Test clause printer

#print("Testing print_clause()")
#print_clause(theorem[0][1])
#print_clause([['p'], ['q']])
#print_clause([['p','s'], ['q','r']])
# Out:
# prover():
#
# Theorem:
# clause 0: p\/q\/~r
# clause 1: s\/~q
# clause 2: t\/~s
# clause 3: ~p
# clause 4: r
# clause 5: ~t
# Goal clause index=3
# resolving: [['p', 'q'], ['r']] and [[], ['p']]
# New clause from resolution of 0 and 3 :q\/~r
# resolving: [['s'], ['q']] and [[], ['p']]
# resolving: [['t'], ['s']] and [[], ['p']]
# resolving: [['p', 'q'], ['r']] and [['r'], []]
# New clause from resolution of 0 and 4 :p\/q
# resolving: [['s'], ['q']] and [['r'], []]
# resolving: [['t'], ['s']] and [['r'], []]
# resolving: [[], ['p']] and [['r'], []]
# resolving: [['p', 'q'], ['r']] and [[], ['t']]
# resolving: [['s'], ['q']] and [[], ['t']]
# resolving: [['t'], ['s']] and [[], ['t']]
# New clause from resolution of 2 and 5 :~s
# resolving: [[], ['p']] and [[], ['t']]
# resolving: [['r'], []] and [[], ['t']]
# resolving: [['p', 'q'], ['r']] and [['q'], ['r']]
# resolving: [['s'], ['q']] and [['q'], ['r']]
# New clause from resolution of 1 and 6 :s\/~r
# resolving: [['t'], ['s']] and [['q'], ['r']]
# resolving: [[], ['p']] and [['q'], ['r']]
# resolving: [['r'], []] and [['q'], ['r']]
# New clause from resolution of 4 and 6 :q
# resolving: [[], ['t']] and [['q'], ['r']]
# resolving: [['p', 'q'], ['r']] and [['p', 'q'], []]
# resolving: [['s'], ['q']] and [['p', 'q'], []]
# New clause from resolution of 1 and 7 :s\/p
# resolving: [['t'], ['s']] and [['p', 'q'], []]
# resolving: [[], ['p']] and [['p', 'q'], []]
# resolving: [['r'], []] and [['p', 'q'], []]
# resolving: [[], ['t']] and [['p', 'q'], []]
# resolving: [['q'], ['r']] and [['p', 'q'], []]
# resolving: [['p', 'q'], ['r']] and [[], ['s']]
# resolving: [['s'], ['q']] and [[], ['s']]
# New clause from resolution of 1 and 8 :~q
# resolving: [['t'], ['s']] and [[], ['s']]
# resolving: [[], ['p']] and [[], ['s']]
# resolving: [['r'], []] and [[], ['s']]
# resolving: [[], ['t']] and [[], ['s']]
# resolving: [['q'], ['r']] and [[], ['s']]
# resolving: [['p', 'q'], []] and [[], ['s']]
# resolving: [['p', 'q'], ['r']] and [['s'], ['r']]
# resolving: [['s'], ['q']] and [['s'], ['r']]
# resolving: [['t'], ['s']] and [['s'], ['r']]
# New clause from resolution of 2 and 9 :t\/~r
# resolving: [[], ['p']] and [['s'], ['r']]
# resolving: [['r'], []] and [['s'], ['r']]
# New clause from resolution of 4 and 9 :s
# resolving: [[], ['t']] and [['s'], ['r']]
# resolving: [['q'], ['r']] and [['s'], ['r']]
# resolving: [['p', 'q'], []] and [['s'], ['r']]
# resolving: [[], ['s']] and [['s'], ['r']]
# New clause from resolution of 8 and 9 :~r
# resolving: [['p', 'q'], ['r']] and [['q'], []]
# resolving: [['s'], ['q']] and [['q'], []]
# resolving: [['t'], ['s']] and [['q'], []]
# resolving: [[], ['p']] and [['q'], []]
# resolving: [['r'], []] and [['q'], []]
# resolving: [[], ['t']] and [['q'], []]
# resolving: [['q'], ['r']] and [['q'], []]
# resolving: [['p', 'q'], []] and [['q'], []]
# resolving: [[], ['s']] and [['q'], []]
# resolving: [['s'], ['r']] and [['q'], []]
# resolving: [['p', 'q'], ['r']] and [['s', 'p'], []]
# resolving: [['s'], ['q']] and [['s', 'p'], []]
# resolving: [['t'], ['s']] and [['s', 'p'], []]
# New clause from resolution of 2 and 11 :t\/p
# resolving: [[], ['p']] and [['s', 'p'], []]
# resolving: [['r'], []] and [['s', 'p'], []]
# resolving: [[], ['t']] and [['s', 'p'], []]
# resolving: [['q'], ['r']] and [['s', 'p'], []]
# resolving: [['p', 'q'], []] and [['s', 'p'], []]
# resolving: [[], ['s']] and [['s', 'p'], []]
# New clause from resolution of 8 and 11 :p
# resolving: [['s'], ['r']] and [['s', 'p'], []]
# resolving: [['q'], []] and [['s', 'p'], []]
# resolving: [['p', 'q'], ['r']] and [[], ['q']]
# New clause from resolution of 0 and 12 :p\/~r
# resolving: [['s'], ['q']] and [[], ['q']]
# resolving: [['t'], ['s']] and [[], ['q']]
# resolving: [[], ['p']] and [[], ['q']]
# resolving: [['r'], []] and [[], ['q']]
# resolving: [[], ['t']] and [[], ['q']]
# resolving: [['q'], ['r']] and [[], ['q']]
# resolving: [['p', 'q'], []] and [[], ['q']]
# resolving: [[], ['s']] and [[], ['q']]
# resolving: [['s'], ['r']] and [[], ['q']]
# resolving: [['q'], []] and [[], ['q']]
# New clause from resolution of 10 and 12 :NULL
#
# Empty clause derived. Theorem is proven!
#
# New Clauses with including null:  14
#
# New Clauses with not including null:  13
# True

# %%
# hw
prover(theorem2, 6)
# Out:
# prover():
#
# Theorem:
# clause 0: i\/~m
# clause 1: m\/~i
# clause 2: m\/l
# clause 3: h\/~i
# clause 4: h\/~l
# clause 5: g\/~h
# clause 6: ~h
# Goal clause index=6
# resolving: [['i'], ['m']] and [[], ['h']]
# resolving: [['m'], ['i']] and [[], ['h']]
# resolving: [['l', 'm'], []] and [[], ['h']]
# resolving: [['h'], ['i']] and [[], ['h']]
# New clause from resolution of 3 and 6 :~i
# resolving: [['h'], ['l']] and [[], ['h']]
# New clause from resolution of 4 and 6 :~l
# resolving: [['g'], ['h']] and [[], ['h']]
# resolving: [['i'], ['m']] and [[], ['i']]
# New clause from resolution of 0 and 7 :~m
# resolving: [['m'], ['i']] and [[], ['i']]
# resolving: [['l', 'm'], []] and [[], ['i']]
# resolving: [['h'], ['i']] and [[], ['i']]
# resolving: [['h'], ['l']] and [[], ['i']]
# resolving: [['g'], ['h']] and [[], ['i']]
# resolving: [[], ['h']] and [[], ['i']]
# resolving: [['i'], ['m']] and [[], ['l']]
# resolving: [['m'], ['i']] and [[], ['l']]
# resolving: [['l', 'm'], []] and [[], ['l']]
# New clause from resolution of 2 and 8 :m
# resolving: [['h'], ['i']] and [[], ['l']]
# resolving: [['h'], ['l']] and [[], ['l']]
# resolving: [['g'], ['h']] and [[], ['l']]
# resolving: [[], ['h']] and [[], ['l']]
# resolving: [[], ['i']] and [[], ['l']]
# resolving: [['i'], ['m']] and [[], ['m']]
# resolving: [['m'], ['i']] and [[], ['m']]
# resolving: [['l', 'm'], []] and [[], ['m']]
# New clause from resolution of 2 and 9 :l
# resolving: [['h'], ['i']] and [[], ['m']]
# resolving: [['h'], ['l']] and [[], ['m']]
# resolving: [['g'], ['h']] and [[], ['m']]
# resolving: [[], ['h']] and [[], ['m']]
# resolving: [[], ['i']] and [[], ['m']]
# resolving: [[], ['l']] and [[], ['m']]
# resolving: [['i'], ['m']] and [['m'], []]
# New clause from resolution of 0 and 10 :i
# resolving: [['m'], ['i']] and [['m'], []]
# resolving: [['l', 'm'], []] and [['m'], []]
# resolving: [['h'], ['i']] and [['m'], []]
# resolving: [['h'], ['l']] and [['m'], []]
# resolving: [['g'], ['h']] and [['m'], []]
# resolving: [[], ['h']] and [['m'], []]
# resolving: [[], ['i']] and [['m'], []]
# resolving: [[], ['l']] and [['m'], []]
# resolving: [[], ['m']] and [['m'], []]
# New clause from resolution of 9 and 10 :NULL
#
# Empty clause derived. Theorem is proven!
#
# New Clauses with including null:  7
#
# New Clauses with not including null:  6
# True

# %%
prover(theorem3, 5)
# Out:
# prover():
#
# Theorem:
# clause 0: a
# clause 1: b
# clause 2: d
# clause 3: c\/~a\/~b
# clause 4: e\/~c\/~d
# clause 5: ~e
# Goal clause index=5
# resolving: [['a'], []] and [[], ['e']]
# resolving: [['b'], []] and [[], ['e']]
# resolving: [['d'], []] and [[], ['e']]
# resolving: [['c'], ['a', 'b']] and [[], ['e']]
# resolving: [['e'], ['d', 'c']] and [[], ['e']]
# New clause from resolution of 4 and 5 :~d\/~c
# resolving: [['a'], []] and [[], ['d', 'c']]
# resolving: [['b'], []] and [[], ['d', 'c']]
# resolving: [['d'], []] and [[], ['d', 'c']]
# New clause from resolution of 2 and 6 :~c
# resolving: [['c'], ['a', 'b']] and [[], ['d', 'c']]
# New clause from resolution of 3 and 6 :~a\/~d\/~b
# resolving: [['e'], ['d', 'c']] and [[], ['d', 'c']]
# resolving: [[], ['e']] and [[], ['d', 'c']]
# resolving: [['a'], []] and [[], ['c']]
# resolving: [['b'], []] and [[], ['c']]
# resolving: [['d'], []] and [[], ['c']]
# resolving: [['c'], ['a', 'b']] and [[], ['c']]
# New clause from resolution of 3 and 7 :~a\/~b
# resolving: [['e'], ['d', 'c']] and [[], ['c']]
# resolving: [[], ['e']] and [[], ['c']]
# resolving: [[], ['d', 'c']] and [[], ['c']]
# resolving: [['a'], []] and [[], ['a', 'd', 'b']]
# New clause from resolution of 0 and 8 :~d\/~b
# resolving: [['b'], []] and [[], ['a', 'd', 'b']]
# New clause from resolution of 1 and 8 :~a\/~d
# resolving: [['d'], []] and [[], ['a', 'd', 'b']]
# resolving: [['c'], ['a', 'b']] and [[], ['a', 'd', 'b']]
# resolving: [['e'], ['d', 'c']] and [[], ['a', 'd', 'b']]
# resolving: [[], ['e']] and [[], ['a', 'd', 'b']]
# resolving: [[], ['d', 'c']] and [[], ['a', 'd', 'b']]
# resolving: [[], ['c']] and [[], ['a', 'd', 'b']]
# resolving: [['a'], []] and [[], ['a', 'b']]
# New clause from resolution of 0 and 9 :~b
# resolving: [['b'], []] and [[], ['a', 'b']]
# New clause from resolution of 1 and 9 :~a
# resolving: [['d'], []] and [[], ['a', 'b']]
# resolving: [['c'], ['a', 'b']] and [[], ['a', 'b']]
# resolving: [['e'], ['d', 'c']] and [[], ['a', 'b']]
# resolving: [[], ['e']] and [[], ['a', 'b']]
# resolving: [[], ['d', 'c']] and [[], ['a', 'b']]
# resolving: [[], ['c']] and [[], ['a', 'b']]
# resolving: [[], ['a', 'd', 'b']] and [[], ['a', 'b']]
# resolving: [['a'], []] and [[], ['d', 'b']]
# resolving: [['b'], []] and [[], ['d', 'b']]
# New clause from resolution of 1 and 10 :~d
# resolving: [['d'], []] and [[], ['d', 'b']]
# resolving: [['c'], ['a', 'b']] and [[], ['d', 'b']]
# resolving: [['e'], ['d', 'c']] and [[], ['d', 'b']]
# resolving: [[], ['e']] and [[], ['d', 'b']]
# resolving: [[], ['d', 'c']] and [[], ['d', 'b']]
# resolving: [[], ['c']] and [[], ['d', 'b']]
# resolving: [[], ['a', 'd', 'b']] and [[], ['d', 'b']]
# resolving: [[], ['a', 'b']] and [[], ['d', 'b']]
# resolving: [['a'], []] and [[], ['a', 'd']]
# resolving: [['b'], []] and [[], ['a', 'd']]
# resolving: [['d'], []] and [[], ['a', 'd']]
# resolving: [['c'], ['a', 'b']] and [[], ['a', 'd']]
# resolving: [['e'], ['d', 'c']] and [[], ['a', 'd']]
# resolving: [[], ['e']] and [[], ['a', 'd']]
# resolving: [[], ['d', 'c']] and [[], ['a', 'd']]
# resolving: [[], ['c']] and [[], ['a', 'd']]
# resolving: [[], ['a', 'd', 'b']] and [[], ['a', 'd']]
# resolving: [[], ['a', 'b']] and [[], ['a', 'd']]
# resolving: [[], ['d', 'b']] and [[], ['a', 'd']]
# resolving: [['a'], []] and [[], ['b']]
# resolving: [['b'], []] and [[], ['b']]
# New clause from resolution of 1 and 12 :NULL
#
# Empty clause derived. Theorem is proven!
#
# New Clauses with including null:  10
#
# New Clauses with not including null:  9
# True
